# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrizzio2901/Practicando-Python/blob/main/challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
ingreso_total = tienda['Precio'].sum()
ingreso_total2 = tienda2['Precio'].sum()
ingreso_total3 = tienda3['Precio'].sum()
ingreso_total4 = tienda4['Precio'].sum()

# %%
print(ingreso_total)
print(ingreso_total2)
print(ingreso_total3)
print(ingreso_total4)
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0

# %%
import matplotlib.pyplot as plt

# Datos consolidados
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [ingreso_total, ingreso_total2, ingreso_total3, ingreso_total4]

plt.bar(tiendas, ingresos, color=['#4CAF50', '#2196F3', '#FF9800', '#F44336'])
plt.title('Ingresos Totales por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ingresos ($)')
plt.savefig('1_ingresos_totales.png')
plt.show()

# %%
# Contar productos por categoría en cada tienda
ventas_cat = tienda['Categoría del Producto'].value_counts()
ventas_cat2 = tienda2['Categoría del Producto'].value_counts()
ventas_cat3 = tienda3['Categoría del Producto'].value_counts()
ventas_cat4 = tienda4['Categoría del Producto'].value_counts()

# Mostrar las categorías más populares de la Tienda 1 como ejemplo
print("Categorías más vendidas - Tienda 1:")
print(ventas_cat)
print("\nCategorías más vendidas - Tienda 2:")
print(ventas_cat2)
print("\nCategorías más vendidas - Tienda 3:")
print(ventas_cat3)
print("\nCategorías más vendidas - Tienda 4:")
print(ventas_cat4)
# Out:
# Categorías más vendidas - Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Categorías más vendidas - Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Categorías más vendidas - Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %%
plt.figure(figsize=(8, 8))
ventas_cat.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='Pastel1')
plt.title('Distribución de Categorías - Tienda 1')
plt.ylabel('') # Quitar etiqueta lateral
plt.savefig('2_categorias_tienda1.png')
plt.show()

# %%
plt.figure(figsize=(8, 8))
ventas_cat2.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='Pastel1')
plt.title('Distribución de Categorías - Tienda 2')
plt.ylabel('') # Quitar etiqueta lateral
plt.savefig('2_categorias_tienda2.png')
plt.show()

# %%
plt.figure(figsize=(8, 8))
ventas_cat3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='Pastel1')
plt.title('Distribución de Categorías - Tienda 3')
plt.ylabel('') # Quitar etiqueta lateral
plt.savefig('2_categorias_tienda3.png')
plt.show()

# %%
plt.figure(figsize=(8, 8))
ventas_cat4.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='Pastel1')
plt.title('Distribución de Categorías - Tienda 4')
plt.ylabel('') # Quitar etiqueta lateral
plt.savefig('2_categorias_tienda4.png')
plt.show()

# %%
media_calificacion = tienda['Calificación'].mean()
print("Media de la Tienda 1:")
print(media_calificacion)

media_calificacion2 = tienda2['Calificación'].mean()
print("\nMedia de la Tienda 2:")
print(media_calificacion2)

media_calificacion3 = tienda3['Calificación'].mean()
print("\nMedia de la Tienda 3:")
print(media_calificacion3)

media_calificacion4 = tienda4['Calificación'].mean()
print("\nMedia de la Tienda 4:")
print(media_calificacion4)
# Out:
# Media de la Tienda 1:
# 3.976685036032217
#
# Media de la Tienda 2:
# 4.037303942348453
#
# Media de la Tienda 3:
# 4.048325561678677
#
# Media de la Tienda 4:
# 3.9957591178965224

# %%
medias = [media_calificacion, media_calificacion2, media_calificacion3, media_calificacion4]

plt.barh(tiendas, medias, color='skyblue')
plt.xlabel('Calificación Promedio (1-5)')
plt.title('Satisfacción del Cliente por Tienda')
plt.xlim(0, 5) # La escala de estrellas es hasta 5
plt.legend()
plt.savefig('3_satisfaccion_cliente.png')
plt.show()
# Out:
# /tmp/ipykernel_181/2862340479.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
articulo_mas_vendido = tienda['Producto'].value_counts().idxmax()
print("Artículo más vendido - Tienda 1:")
print(articulo_mas_vendido)

articulo_menos_vendido = tienda['Producto'].value_counts().idxmin()
print("\nArtículo menos vendido - Tienda 1:")
print(articulo_menos_vendido)

articulo_mas_vendido2 = tienda2['Producto'].value_counts().idxmax()
print("\nArtículo más vendido - Tienda 2:")
print(articulo_mas_vendido2)

articulo_menos_vendido2 = tienda2['Producto'].value_counts().idxmin()
print("\nArtículo menos vendido - Tienda 2:")
print(articulo_menos_vendido2)

articulo_mas_vendido3 = tienda3['Producto'].value_counts().idxmax()
print("\nArtículo más vendido - Tienda 3:")
print(articulo_mas_vendido3)

articulo_menos_vendido3 = tienda3['Producto'].value_counts().idxmin()
print("\nArtículo menos vendido - Tienda 3:")
print(articulo_menos_vendido3)

articulo_mas_vendido4 = tienda4['Producto'].value_counts().idxmax()
print("\nArtículo más vendido - Tienda 4:")
print(articulo_mas_vendido4)

articulo_menos_vendido4 = tienda4['Producto'].value_counts().idxmin()
print("\nArtículo menos vendido - Tienda 4:")
print(articulo_menos_vendido4)
# Out:
# Artículo más vendido - Tienda 1:
# Microondas
#
# Artículo menos vendido - Tienda 1:
# Auriculares con micrófono
#
# Artículo más vendido - Tienda 2:
# Iniciando en programación
#
# Artículo menos vendido - Tienda 2:
# Juego de mesa
#
# Artículo más vendido - Tienda 3:
# Kit de bancas
#
# Artículo menos vendido - Tienda 3:
# Bloques de construcción
#
# Artículo más vendido - Tienda 4:
# Cama box
#
# Artículo menos vendido - Tienda 4:
# Guitarra eléctrica

# %%
promedio_envio = tienda['Costo de envío'].mean()
print("Promedio de costo de envío - Tienda 1:")
print(promedio_envio)

promedio_envio = tienda2['Costo de envío'].mean()
print("\nPromedio de costo de envío - Tienda 2:")
print(promedio_envio)

promedio_envio = tienda3['Costo de envío'].mean()
print("\nPromedio de costo de envío - Tienda 3:")
print(promedio_envio)

promedio_envio = tienda4['Costo de envío'].mean()
print("\nPromedio de costo de envío - Tienda 4:")
print(promedio_envio)
# Out:
# Promedio de costo de envío - Tienda 1:
# 26018.60958033065
#
# Promedio de costo de envío - Tienda 2:
# 25216.235693090293
#
# Promedio de costo de envío - Tienda 3:
# 24805.680373039424
#
# Promedio de costo de envío - Tienda 4:
# 23459.457167090754

# %%
envios = [tienda['Costo de envío'].mean(), tienda2['Costo de envío'].mean(),
          tienda3['Costo de envío'].mean(), tienda4['Costo de envío'].mean()]

plt.scatter(envios, ingresos, s=200, c=['green', 'blue', 'orange', 'red'], alpha=0.7)

# Anotar los puntos
for i, txt in enumerate(tiendas):
    plt.annotate(txt, (envios[i], ingresos[i]), xytext=(5,5), textcoords='offset points')

plt.title('Relación: Costo de Envío vs Ingresos')
plt.xlabel('Costo de Envío Promedio')
plt.ylabel('Ingresos Totales')
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('4_envio_vs_ingresos.png')
plt.show()

# %% [markdown]
# # Informe Final: Análisis de Decisiones Alura Store
#
# ### 1. Introducción
# Este análisis detalla el rendimiento de las cuatro sucursales de Alura Store para determinar cuál debe ser vendida. Se han procesado métricas de ingresos totales, volumen de ventas por categoría, satisfacción del cliente (ratings), productos estrella y costos de logística para fundamentar la recomendación al Sr. Juan.
#
# ---
#
# ### 2. Hallazgos Clave del Análisis
#
# #### A. Rendimiento Financiero
# Existe una brecha considerable entre la mejor y la peor sucursal:
# * **Tienda 1 (Líder):** $1,150,880,400.00
# * **Tienda 4 (Menor rendimiento):** $1,038,375,700.00
#
# > **Nota:** La Tienda 4 está generando aproximadamente **$112 millones menos** que la Tienda 1.
#
# #### B. Categorías y Productos
# * **Dominio del mercado:** En las 4 tiendas, Muebles y Electrónicos son las categorías más populares.
# * **Productos Estrella:** Mientras la Tienda 1 destaca con productos de alta rotación como el **Microondas**, la Tienda 4 depende de la **Cama box**.
# * **Debilidades:** La Tienda 4 presenta su menor volumen en Instrumentos musicales (solo 170 ventas), siendo su artículo menos vendido la **Guitarra eléctrica**.
#
# #### C. Satisfacción y Logística
# * **Calificaciones:** Las tiendas 2 y 3 lideran en satisfacción del cliente (aprox. 4.04). La Tienda 1 tiene el promedio más bajo (3.97), seguida por la Tienda 4 (3.99).
# * **Eficiencia de Envío:** La Tienda 4 tiene el costo de envío promedio más bajo ($23,459). A pesar de esta ventaja competitiva en costos, no ha sido suficiente para impulsar sus ingresos por encima de las demás sucursales.
#
# ---
#
# ### 3. Recomendación Final
# **Se recomienda al Sr. Juan vender la TIENDA 4.**
#
# **Justificación:**
# 1. **Ingresos Insuficientes:** A pesar de contar con la logística de envío más económica, es la que menos ingresos aporta al grupo. Esto sugiere que el problema no es el costo operativo, sino una falta de demanda o volumen en su ubicación actual.
# 2. **Eficiencia Desaprovechada:** Es un punto crítico que, teniendo el envío más barato, no logre superar en ingresos a tiendas con costos logísticos más elevados (como la Tienda 1), lo que indica una baja tasa de conversión de ventas.
# ---
# **Analista:** Luis Fabrizzio

# %%
import pandas as pd

# Crear el diccionario con los datos analizados
datos_finales = {
    'Métrica': [
        'Ingresos Totales',
        'Media Calificación',
        'Costo Envío Prom.'
    ],
    'Tienda 1': ['$1,150.8M', '3.97', '$26,018'],
    'Tienda 2': ['$1,116.3M', '4.03', '$25,216'],
    'Tienda 3': ['$1,098.0M', '4.04', '$24,805'],
    'Tienda 4': ['$1,038.3M', '3.99', '$23,459']
}

# Crear el DataFrame
df_resumen = pd.DataFrame(datos_finales)

# Mostrar la tabla con formato limpio
print("RESUMEN VISUAL DE MÉTRICAS")
display(df_resumen)
# Out:
# RESUMEN VISUAL DE MÉTRICAS
#               Métrica   Tienda 1   Tienda 2   Tienda 3   Tienda 4
# 0    Ingresos Totales  $1,150.8M  $1,116.3M  $1,098.0M  $1,038.3M
# 1  Media Calificación       3.97       4.03       4.04       3.99
# 2   Costo Envío Prom.    $26,018    $25,216    $24,805    $23,459
